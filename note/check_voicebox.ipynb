# %%
import requests
import json

# %%
url = "http://127.0.0.1:50021/"
text = "こんにちは"
speaker_id = 1
item_data = {
    ('text', text),
    ('speaker', 3),
}

# %%
res = requests.post(url+"audio_query", params=item_data)
res_json = res.json()
print(res_json)
# Out:
# {'accent_phrases': [{'moras': [{'text': 'コ', 'consonant': 'k', 'consonant_length': 0.09125996381044388, 'vowel': 'o', 'vowel_length': 0.1464204490184784, 'pitch': 5.689502716064453}, {'text': 'ン', 'consonant': None, 'consonant_length': None, 'vowel': 'N', 'vowel_length': 0.07110699266195297, 'pitch': 5.868537902832031}, {'text': 'ニ', 'consonant': 'n', 'consonant_length': 0.032809846103191376, 'vowel': 'i', 'vowel_length': 0.09959951788187027, 'pitch': 5.991527080535889}, {'text': 'チ', 'consonant': 'ch', 'consonant_length': 0.08417008072137833, 'vowel': 'i', 'vowel_length': 0.07654798775911331, 'pitch': 5.978631973266602}, {'text': 'ワ', 'consonant': 'w', 'consonant_length': 0.07711347937583923, 'vowel': 'a', 'vowel_length': 0.18254642188549042, 'pitch': 6.040229797363281}], 'accent': 5, 'pause_mora': None, 'is_interrogative': False}], 'speedScale': 1.0, 'pitchScale': 0.0, 'intonationScale': 1.0, 'volumeScale': 1.0, 'prePhonemeLength': 0.1, 'postPhonemeLength': 0.1, 'outputSamplingRate
# ...
